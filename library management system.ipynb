# %%
class Book:
  def __init__(self, title, author, isbn):
    self.title = title
    self.author = author
    self.isbn = isbn
    self.available = True

  def __str__(self):
    return f"Title: {self.title}\nAuthor: {self.author}\nISBN: {self.isbn}\nAvailable: {self.available}"

class Library:
  def __init__(self):
    self.books = []

  def add_book(self, book):
    self.books.append(book)

  def find_book(self, query):
    result = []
    for book in self.books:
      if query.lower() in book.title.lower() or query.lower() in book.author.lower() or query.lower() in book.isbn.lower():
        result.append(book)
    return result

  def borrow_book(self, isbn):
    for book in self.books:
      if book.isbn == isbn and book.available:
        book.available = False
        print(f"You have borrowed '{book.title}'")
        return
    print("Book not found or unavailable.")

  def return_book(self, isbn):
    for book in self.books:
      if book.isbn == isbn and not book.available:
        book.available = True
        print(f"You have returned '{book.title}'")
        return
    print("Invalid ISBN or book was not borrowed.")

  def display_books(self):
    if not self.books:
      print("No books in the library.")
    else:
      for book in self.books:
        print(book)
        print("-" * 20)

# Example usage:
library = Library()

# Adding books
book1 = Book("The Hitchhiker's Guide to the Galaxy", "Douglas Adams", "978-0345391803")
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Displaying all books
library.display_books()

# Searching for a book
search_results = library.find_book("Pride")
for book in search_results:
  print(book)
  print("-" * 20)
# Out:
# Title: The Hitchhiker's Guide to the Galaxy
# Author: Douglas Adams
# ISBN: 978-0345391803
# Available: True
# --------------------
# Title: Pride and Prejudice
# Author: Jane Austen
# ISBN: 978-0141439518
# Available: True
# --------------------
# Title: To Kill a Mockingbird
# Author: Harper Lee
# ISBN: 978-0061120083
# Available: True
# --------------------
# Title: Pride and Prejudice
# Author: Jane Austen
# ISBN: 978-0141439518
# Available: True
# --------------------
# You have borrowed 'The Hitchhiker's Guide to the Galaxy'
# You have returned 'The Hitchhiker's Guide to the Galaxy'

# %%
# Borrowing a book
library.borrow_book("978-0345391803")

# Returning a book
library.return_book("978-0345391803")

book2 = Book("Pride and Prejudice", "Jane Austen", "978-0141439518")
book3 = Book("To Kill a Mockingbird", "Harper Lee", "978-0061120083")

# %%
# prompt: library management to search for a specific book

class Book:
  def __init__(self, title, author, isbn):
    self.title = title
    self.author = author
    self.isbn = isbn
    self.available = True

  def __str__(self):
    return f"Title: {self.title}\nAuthor: {self.author}\nISBN: {self.isbn}\nAvailable: {self.available}"

class Library:
  def __init__(self):
    self.books = []

  def add_book(self, book):
    self.books.append(book)

  def find_book(self, query):
    result = []
    for book in self.books:
      if query.lower() in book.title.lower() or query.lower() in book.author.lower() or query.lower() in book.isbn.lower():
        result.append(book)
    return result

  def borrow_book(self, isbn):
    for book in self.books:
      if book.isbn == isbn and book.available:
        book.available = False
        print(f"You have borrowed '{book.title}'")
        return
    print("Book not found or unavailable.")

  def return_book(self, isbn):
    for book in self.books:
      if book.isbn == isbn and not book.available:
        book.available = True
        print(f"You have returned '{book.title}'")
        return
    print("Invalid ISBN or book was not borrowed.")

  def display_books(self):
    if not self.books:
      print("No books in the library.")
    else:
      for book in self.books:
        print(book)
        print("-" * 20)

# Example usage:
library = Library()

# Adding books
book1 = Book("The Hitchhiker's Guide to the Galaxy", "Douglas Adams", "978-0345391803")
book2 = Book("Pride and Prejudice", "Jane Austen", "978-0141439518")
book3 = Book("To Kill a Mockingbird", "Harper Lee", "978-0061120083")
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

# Search for a specific book
search_query = input("Enter search query: ")
search_results = library.find_book(search_query)

if search_results:
  print("Search results:")
  for book in search_results:
    print(book)
    print("-" * 20)
else:
  print("No books found matching your query.")
